# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivShah19/movie-R/blob/main/Movie_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
movies = pd.read_csv('/content/drive/MyDrive/Movie/tmdb_5000_movies.csv')
credits = pd.read_csv('/content/drive/MyDrive/Movie/tmdb_5000_credits.csv')

# %%
movies.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.head(5)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies = movies.merge(credits, on="title")

# %%
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
movies = movies[['id','title','genres','overview','keywords','cast','crew', 'vote_average', 'vote_count']]
movies
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            4809 non-null   int64
#  1   title         4809 non-null   object
#  2   genres        4809 non-null   object
#  3   overview      4806 non-null   object
#  4   keywords      4809 non-null   object
#  5   cast          4809 non-null   object
#  6   crew          4809 non-null   object
#  7   vote_average  4809 non-null   float64
#  8   vote_count    4809 non-null   int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 375.7+ KB

# %%
movies.isnull().sum()
# Out:
# id              0
# title           0
# genres          0
# overview        3
# keywords        0
# cast            0
# crew            0
# vote_average    0
# vote_count      0
# dtype: int64

# %%
movies = movies.dropna()

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.isnull().sum()
# Out:
# id              0
# title           0
# genres          0
# overview        0
# keywords        0
# cast            0
# crew            0
# vote_average    0
# vote_count      0
# dtype: int64

# %%
mean = movies['vote_average'].mean()
mean
# Out:
# 6.093258426966292

# %%
quan = movies['vote_count'].quantile(0.95)
quan
# Out:
# 3040.75

# %%
Best_movies = movies[movies['vote_count'] >=quan ]
Best_movies.head(5)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 5     559                              Spider-Man 3
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 5  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 5  The seemingly invincible Spider-Man goes up ag...
#
# ...

# %%
def weighted_rating(x):
  v = x['vote_count']
  r = x['vote_average']
  return (v/(v+quan) * r) + (quan/(quan+v) * mean)

# %%
Best_movies['rating'] = Best_movies.apply(weighted_rating, axis=1)
Best_movies.head(5)
# Out:
# <ipython-input-21-792c4bf312e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Best_movies['rating'] = Best_movies.apply(weighted_rating, axis=1)
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 5     559                              Spider-Man 3
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
Best_movies = Best_movies.sort_values('rating', ascending=False)
Best_movies = Best_movies[['id','title', 'rating']]

# %%
Best_movies
# Out:
#           id                               title    rating
# 1887     278            The Shawshank Redemption  7.849239
# 65       155                     The Dark Knight  7.774142
# 662      550                          Fight Club  7.761194
# 96     27205                           Inception  7.736629
# 3237     680                        Pulp Fiction  7.714919
# ...      ...                                 ...       ...
# 37     68728          Oz: The Great and Powerful  5.881988
# 9     209112  Batman v Superman: Dawn of Justice  5.819047
# 59     14161                                2012  5.788812
# 1157  216015                Fifty Shades of Grey  5.631499
# 337    47964              A Good Day to Die Hard  5.615715
#
# [241 rows x 3 columns]

# %%
movies
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
import ast

# %%
movies.head(5)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
# ...

# %%
def convert(obj):
  l = []
  for i in ast.literal_eval(obj):
    l.append(i['name'])
  return l

# %%
movies['genres'] = movies['genres'].apply(convert)
movies['keywords'] = movies['keywords'].apply(convert)
movies['cast'] = movies['cast'].apply(convert)
# Out:
# <ipython-input-28-9ed9572c64fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres'] = movies['genres'].apply(convert)
# <ipython-input-28-9ed9572c64fb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['keywords'] = movies['keywords'].apply(convert)
# <ipython-input-28-9ed9572c64fb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
movies.head(5)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
# ...

# %%
def fetch_director(obj):
    l = []

    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            l.append(i['name'])
            break
    return l

# %%
movies['crew'] = movies['crew'].apply(fetch_director)
# Out:
# <ipython-input-31-1e2791f73e30>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies['crew']
# Out:
# 0           [James Cameron]
# 1          [Gore Verbinski]
# 2              [Sam Mendes]
# 3       [Christopher Nolan]
# 4          [Andrew Stanton]
#                ...
# 4804     [Robert Rodriguez]
# 4805         [Edward Burns]
# 4806          [Scott Smith]
# 4807          [Daniel Hsia]
# 4808     [Brian Herzlinger]
# Name: crew, Length: 4806, dtype: object

# %%
movies.sample(5)
# Out:
#          id            title                                           genres  \
# 723    8645    The Happening                      [Thriller, Science Fiction]
# 106     810  Shrek the Third  [Fantasy, Adventure, Animation, Comedy, Family]
# 3426  16620         La Bamba                                   [Drama, Music]
# 1210  10761    Made of Honor                                [Comedy, Romance]
# 2750  15489         Snow Day                                 [Comedy, Family]
#
#                                                overview  \
# 723   When a deadly airborne virus threatens to wipe...
# 106   The King of Far Far Away has died and Shrek an...
# 3426  Biographical story of the rise from nowhere of...
# 1210  Tom and Hannah have been platonic friends for ...
# 2750  When a school in upstate New York is snowed in...
#
#                                                keywords  \
# 723   [tree, natural disaster, crisis, park, strange...
# ...

# %%
movies = movies.drop(columns=['vote_average', 'vote_count'])

# %%
movies
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                              genres  \
# 0     [Action, Adventure, Fantasy, Science Fiction]
# 1                      [Adventure, Fantasy, Action]
# 2                        [Action, Adventure, Crime]
# 3                  [Action, Crime, Drama, Thriller]
# ...

# %%
genres_movie_list = movies[['title','genres']]
genres_movie_list = genres_movie_list.merge(Best_movies, on="title")
genres_movie_list
# Out:
#                                         title  \
# 0                                      Avatar
# 1    Pirates of the Caribbean: At World's End
# 2                                     Spectre
# 3                       The Dark Knight Rises
# 4                                Spider-Man 3
# ..                                        ...
# 236                        The Usual Suspects
# 237                                   Memento
# 238                              Donnie Darko
# 239                                  Whiplash
# 240                            Reservoir Dogs
#
#                                             genres      id    rating
# 0    [Action, Adventure, Fantasy, Science Fiction]   19995  6.973238
# 1                     [Adventure, Fantasy, Action]     285  6.574688
# 2                       [Action, Adventure, Crime]  206647  6.216255
# 3                 [Action, Crime, Drama, Thriller]   49026  7.222811
# ...

# %%
def remove_spacing(obj):
  l = []
  for i in obj:
    l.append(i.replace(" ",""))
  return l

# %%
movies['genres'] = movies['genres'].apply(remove_spacing)
movies['keywords'] = movies['keywords'].apply(remove_spacing)
movies['cast'] = movies['cast'].apply(remove_spacing)
movies['crew'] = movies['crew'].apply(remove_spacing)

# %%
movies.rename(columns = {'crew':'director'}, inplace = True)

# %%
movies.sample(5)
# Out:
#          id                          title                     genres  \
# 736    3512  Under Siege 2: Dark Territory         [Action, Thriller]
# 1724  10439                    Hocus Pocus  [Comedy, Family, Fantasy]
# 1545   9032                      Big Daddy            [Comedy, Drama]
# 2379  10549                         Hamlet                    [Drama]
# 824    1402       The Pursuit of Happyness                    [Drama]
#
#                                                overview  \
# 736   A passenger train has been hijacked by an elec...
# 1724  After 300 years of slumber, three sister witch...
# 1545  A lazy law school grad adopts a kid to impress...
# 2379  Hamlet, Prince of Denmark, returns home to fin...
# 824   The true story of Christopher Gardner, who inv...
#
#                                                keywords  \
# 736   [terrorist, pentagon, satellite, navyseal, train]
# 1724  [witch, halloween, salem, trickortreating, spe...
# ...

# %%
# combining all relevent data

movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['director']

# %%
data = movies.drop(columns=['overview', 'genres', 'keywords', 'cast', 'director'])

# %%
data
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# ...

# %%
data['tags'] = data['tags'].apply(lambda x:" ".join(x))
data.head(5)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
data['tags'] = data['tags'].apply(lambda x:x.lower())

# %% [markdown]
# **Feature selection part**

# %%
# CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000, stop_words='english')

# %%
vector = cv.fit_transform(data['tags']).toarray()

# %%
vector.shape
# Out:
# (4806, 5000)

# %%
# cosine_similarity

from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.07142857, 0.05216405, ..., 0.02326211, 0.02571722,
#         0.        ],
#        [0.07142857, 1.        , 0.07824608, ..., 0.02326211, 0.        ,
#         0.        ],
#        [0.05216405, 0.07824608, 1.        , ..., 0.02548236, 0.        ,
#         0.        ],
#        ...,
#        [0.02326211, 0.02326211, 0.02548236, ..., 1.        , 0.07537784,
#         0.05025189],
#        [0.02571722, 0.        , 0.        , ..., 0.07537784, 1.        ,
#         0.05555556],
#        [0.        , 0.        , 0.        , ..., 0.05025189, 0.05555556,
#         1.        ]])

# %%
data[data['title'] == "Inception"].index[0]
# Out:
# 96

# %%
distance = sorted(list(enumerate(similarity[96])), reverse=True, key = lambda x:x[1])
distance
# Out:
# [(96, 1.0),
#  (1721, 0.21029989116983447),
#  (1458, 0.19727878476642874),
#  (4405, 0.18983159915049982),
#  (2820, 0.18668326147193276),
#  (613, 0.17937400083354382),
#  (1276, 0.17574991006549873),
#  (370, 0.17155007848855516),
#  (3978, 0.16979054399120352),
#  (1574, 0.16972071444106068),
#  (861, 0.1643989873053573),
#  (1270, 0.1643989873053573),
#  (4010, 0.1643989873053573),
#  (2901, 0.16439898730535726),
#  (3968, 0.16120647005479025),
#  (1792, 0.1600142241187995),
#  (1437, 0.15949044456578),
#  (3303, 0.15949044456578),
#  (922, 0.15819299929208316),
#  (2404, 0.15660307954993902),
#  (1306, 0.1553424415003),
#  (2162, 0.1537811713073114),
#  (322, 0.15220388682955233),
#  (2213, 0.15110651212172094),
#  (127, 0.15086285728094284),
#  (1453, 0.15007505629691606),
#  (176, 0.14763464883937316),
#  (1004, 0.14763464883937316),
#  (1623, 0.14704292441876157),
#  (2521, 0.14704292441876154),
#  (3721, 0.14704292441876154),
#  (4048, 0.14615084586538157),
# ...

# %%
def recommend(movie):
  index = data[data['title'] == movie].index[0]
  distance = sorted(list(enumerate(similarity[index])), reverse=True, key = lambda x:x[1])

  for i in distance[1:6]:
    print(data.iloc[i[0]].title)

# %%
recommend('Avatar')
# Out:
# Lifeforce
# Aliens vs Predator: Requiem
# Battle: Los Angeles
# Titan A.E.
# Independence Day

# %%
import pickle
import gzip

# %%
with open('/content/drive/MyDrive/Movie/movies.pkl', 'wb') as f:
    pickle.dump(data, f)

with gzip.open('/content/drive/MyDrive/Movie/similarity.pkl.gz', 'wb') as f:
    pickle.dump(similarity, f)

with open('/content/drive/MyDrive/Movie/Best_movies.pkl', 'wb') as f:
    pickle.dump(Best_movies, f)

with open('/content/drive/MyDrive/Movie/genres_movie_list', 'wb') as f:
    pickle.dump(genres_movie_list, f)

# %%
data['title'].values
# Out:
# array(['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre',
#        ..., 'Signed, Sealed, Delivered', 'Shanghai Calling',
#        'My Date with Drew'], dtype=object)

# %%
data.to_dict()

# %%
pickle.dump(data.to_dict(), open('/content/drive/MyDrive/Movie/movie_dict.pkl', 'wb'))
